# %% [markdown]
# # Linear Regression Assignment - Mandar Dhumal
# ### Bike Sharing
# #### Problem Statement
# A bike-sharing system is a service in which bikes are made available for shared use to individuals on a short term basis for a price or free. Many bike share systems allow people to borrow a bike from a "dock" which is usually computer-controlled wherein the user enters the payment information, and the system unlocks it. This bike can then be returned to another dock belonging to the same system.
#
#
# A US bike-sharing provider BoomBikes has recently suffered considerable dips in their revenues due to the ongoing Corona pandemic. The company is finding it very difficult to sustain in the current market scenario. So, it has decided to come up with a mindful business plan to be able to accelerate its revenue as soon as the ongoing lockdown comes to an end, and the economy restores to a healthy state.
#
#
# In such an attempt, BoomBikes aspires to understand the demand for shared bikes among the people after this ongoing quarantine situation ends across the nation due to Covid-19. They have planned this to prepare themselves to cater to the people's needs once the situation gets better all around and stand out from other service providers and make huge profits.

# %% [markdown]
# **BoomBikes wants to understand the factors on which the demand for these shared bikes depends.**
#
# **Specifically, they want to understand the factors affecting the demand for these shared bikes in the American market.**
#
# **The company wants to know:**
# - Which variables are significant in predicting the demand for shared bikes.
# - How well those variables describe the bike demands

# %% [markdown]
# #### Business Goals
# You are required to model the demand for shared bikes with the available independent variables. It will be used by the management to understand how exactly the demands vary with different features. They can accordingly manipulate the business strategy to meet the demand levels and meet the customer's expectations. Further, the model will be a good way for management to understand the demand dynamics of a new market.

# %% [markdown]
# ### Step 1: Reading and Understanding the Data

# %%
# Importing required libraries
import numpy as np, pandas as pd, matplotlib.pyplot as plt, seaborn as sns

import sklearn 
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import r2_score
from sklearn.linear_model import LinearRegression
from sklearn.feature_selection import RFE

import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor

import warnings
warnings.filterwarnings('ignore')

# %%
# Reading the dataset
bike = pd.read_csv('day.csv')
bike
# Out:
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday
# 0          1  01-01-2018       1   0     1        0        6           0  \
# 1          2  02-01-2018       1   0     1        0        0           0
# 2          3  03-01-2018       1   0     1        0        1           1
# 3          4  04-01-2018       1   0     1        0        2           1
# 4          5  05-01-2018       1   0     1        0        3           1
# ..       ...         ...     ...  ..   ...      ...      ...         ...
# 725      726  27-12-2019       1   1    12        0        4           1
# 726      727  28-12-2019       1   1    12        0        5           1
# 727      728  29-12-2019       1   1    12        0        6           0
# 728      729  30-12-2019       1   1    12        0        0           0
# 729      730  31-12-2019       1   1    12        0        1           1
#
#      weathersit       temp     atemp      hum  windspeed  casual  registered
# 0             2  14.110847  18.18125  80.5833  10.749882     331         654  \
# 1             2  14.902598  17.68695  69.6087  16.652113     131         670
# 2             1   8.050924   9.47025  43.7273  16.636703     120        1229
# 3             1   8.200000  10.60610  59.0435  10.739832     108        1454
# 4             1   9.305237  11.46350  43.6957  12.522300      82        1518
# ..          ...        ...       ...      ...        ...     ...         ...
# 725           2  10.420847  11.33210  65.2917  23.458911     247        1867
# 726           2  10.386653  12.75230  59.0000  10.416557     644        2451
# 727           2  10.386653  12.12000  75.2917   8.333661     159        1182
# 728           1  10.489153  11.58500  48.3333  23.500518     364        1432
# 729           2   8.849153  11.17435  57.7500  10.374682     439        2290
#
#       cnt
# 0     985
# 1     801
# 2    1349
# 3    1562
# 4    1600
# ..    ...
# 725  2114
# 726  3095
# 727  1341
# 728  1796
# 729  2729
#
# [730 rows x 16 columns]

# %%
# Shape of the dataset
bike.shape
# Out:
# (730, 16)

# %%
# Checking the info
bike.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 730 entries, 0 to 729
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     730 non-null    int64
#  1   dteday      730 non-null    object
#  2   season      730 non-null    int64
#  3   yr          730 non-null    int64
#  4   mnth        730 non-null    int64
#  5   holiday     730 non-null    int64
#  6   weekday     730 non-null    int64
#  7   workingday  730 non-null    int64
#  8   weathersit  730 non-null    int64
#  9   temp        730 non-null    float64
#  10  atemp       730 non-null    float64
#  11  hum         730 non-null    float64
#  12  windspeed   730 non-null    float64
#  13  casual      730 non-null    int64
#  14  registered  730 non-null    int64
#  15  cnt         730 non-null    int64
# dtypes: float64(4), int64(11), object(1)
# memory usage: 91.4+ KB

# %% [markdown]
# #### The dataset has no null values and has 730 rows and 16 columns
# #### Dtype of all the columns are either int64 or float64 except dteday which is object

# %%
bike.describe()
# Out:
#           instant      season          yr        mnth     holiday     weekday
# count  730.000000  730.000000  730.000000  730.000000  730.000000  730.000000  \
# mean   365.500000    2.498630    0.500000    6.526027    0.028767    2.997260
# std    210.877136    1.110184    0.500343    3.450215    0.167266    2.006161
# min      1.000000    1.000000    0.000000    1.000000    0.000000    0.000000
# 25%    183.250000    2.000000    0.000000    4.000000    0.000000    1.000000
# 50%    365.500000    3.000000    0.500000    7.000000    0.000000    3.000000
# 75%    547.750000    3.000000    1.000000   10.000000    0.000000    5.000000
# max    730.000000    4.000000    1.000000   12.000000    1.000000    6.000000
#
#        workingday  weathersit        temp       atemp         hum   windspeed
# count  730.000000  730.000000  730.000000  730.000000  730.000000  730.000000  \
# mean     0.683562    1.394521   20.319259   23.726322   62.765175   12.763620
# std      0.465405    0.544807    7.506729    8.150308   14.237589    5.195841
# min      0.000000    1.000000    2.424346    3.953480    0.000000    1.500244
# 25%      0.000000    1.000000   13.811885   16.889713   52.000000    9.041650
# 50%      1.000000    1.000000   20.465826   24.368225   62.625000   12.125325
# 75%      1.000000    2.000000   26.880615   30.445775   72.989575   15.625589
# max      1.000000    3.000000   35.328347   42.044800   97.250000   34.000021
#
#             casual   registered          cnt
# count   730.000000   730.000000   730.000000
# mean    849.249315  3658.757534  4508.006849
# std     686.479875  1559.758728  1936.011647
# min       2.000000    20.000000    22.000000
# 25%     316.250000  2502.250000  3169.750000
# 50%     717.000000  3664.500000  4548.500000
# 75%    1096.500000  4783.250000  5966.000000
# max    3410.000000  6946.000000  8714.000000

# %% [markdown]
# ### Step 2: Cleaning the data

# %%
# Checking null values
bike.isnull().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %% [markdown]
# #### Converting few columns to categorical columns for better readability of the dataset

# %%
# Season column conversion to categorical.
bike.season.replace({1:'Spring',2:'Summer',3:'Fall',4:'Winter'},inplace=True)

# %%
# weathersit column conversion to categorical.
bike.weathersit.replace({1:'Pleasant',2:'Moderate',3:'Bad',4:'Severe'},inplace=True)

# %%
# Checking whether the changes has taken place
bike.head()
# Out:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday
# 0        1  01-01-2018  Spring   0     1        0        6           0  \
# 1        2  02-01-2018  Spring   0     1        0        0           0
# 2        3  03-01-2018  Spring   0     1        0        1           1
# 3        4  04-01-2018  Spring   0     1        0        2           1
# 4        5  05-01-2018  Spring   0     1        0        3           1
#
#   weathersit       temp     atemp      hum  windspeed  casual  registered
# 0   Moderate  14.110847  18.18125  80.5833  10.749882     331         654  \
# 1   Moderate  14.902598  17.68695  69.6087  16.652113     131         670
# 2   Pleasant   8.050924   9.47025  43.7273  16.636703     120        1229
# 3   Pleasant   8.200000  10.60610  59.0435  10.739832     108        1454
# 4   Pleasant   9.305237  11.46350  43.6957  12.522300      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600

# %%
# mnth column conversion to categorical
bike.mnth.replace({1:'January',2:'February',3:'March',4:'April',5:'May',6:'June',7:'July',8:'August',9:'September',
                   10:'October',11:'November',12:'December'},inplace=True)

# %%
# weekday column conversion to categorical
bike.weekday.replace({0:'Sunday',1:'Monday',2:'Tuesday',3:'Wednesday',4:'Thursday',5:'Friday',6:'Saturday'},inplace=True)

# %%
# Checking whether the changes has taken place
bike.head()
# Out:
#    instant      dteday  season  yr     mnth  holiday    weekday  workingday
# 0        1  01-01-2018  Spring   0  January        0   Saturday           0  \
# 1        2  02-01-2018  Spring   0  January        0     Sunday           0
# 2        3  03-01-2018  Spring   0  January        0     Monday           1
# 3        4  04-01-2018  Spring   0  January        0    Tuesday           1
# 4        5  05-01-2018  Spring   0  January        0  Wednesday           1
#
#   weathersit       temp     atemp      hum  windspeed  casual  registered
# 0   Moderate  14.110847  18.18125  80.5833  10.749882     331         654  \
# 1   Moderate  14.902598  17.68695  69.6087  16.652113     131         670
# 2   Pleasant   8.050924   9.47025  43.7273  16.636703     120        1229
# 3   Pleasant   8.200000  10.60610  59.0435  10.739832     108        1454
# 4   Pleasant   9.305237  11.46350  43.6957  12.522300      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600

# %%
# Dropping column instant as it has no effect on target column, and dteday as we have already mnth and weekday columns
# As model targets on cnt column and cnt is sum of casual and registered, we can drop casual and registered columns

bike.drop(['instant','dteday','casual','registered'], axis=1, inplace=True)

# %%
# Checking whether the changes has taken place
bike.head()
# Out:
#    season  yr     mnth  holiday    weekday  workingday weathersit       temp
# 0  Spring   0  January        0   Saturday           0   Moderate  14.110847  \
# 1  Spring   0  January        0     Sunday           0   Moderate  14.902598
# 2  Spring   0  January        0     Monday           1   Pleasant   8.050924
# 3  Spring   0  January        0    Tuesday           1   Pleasant   8.200000
# 4  Spring   0  January        0  Wednesday           1   Pleasant   9.305237
#
#       atemp      hum  windspeed   cnt
# 0  18.18125  80.5833  10.749882   985
# 1  17.68695  69.6087  16.652113   801
# 2   9.47025  43.7273  16.636703  1349
# 3  10.60610  59.0435  10.739832  1562
# 4  11.46350  43.6957  12.522300  1600

# %%
# Checking for the outliers
plt.figure(figsize=(20,10))
plt.subplot(1,4,1)
sns.boxplot(y='temp', data=bike)
plt.subplot(1,4,2)
sns.boxplot(y='atemp', data=bike)
plt.subplot(1,4,3)
sns.boxplot(y='hum', data=bike)
plt.subplot(1,4,4)
sns.boxplot(y='windspeed', data=bike)
plt.show()

# %% [markdown]
# **We do not need to work on the outliers in the dataset**

# %% [markdown]
# ### Step 3: EDA

# %%
#Checking the seasonal impact on the total count of rental bikes
round(bike.groupby('season')['cnt'].sum()/bike.cnt.sum()*100,2)
# Out:
# season
# Fall      32.24
# Spring    14.27
# Summer    27.91
# Winter    25.57
# Name: cnt, dtype: float64

# %%
# Ploting a pie chart for better visualisation
plt.figure(figsize=(8,8))
bike.groupby(["season"])["cnt"].sum().plot.pie()
plt.title("Seasonal Impact on Bike Rentals",fontsize=20)
plt.show()

# %% [markdown]
# **It can be observed that Spring has least bike rentals while Fall has the highest bike rentals**

# %%
#Checking the yearwise count of rental bikes
round(bike.groupby('yr')['cnt'].sum()/bike.cnt.sum()*100,2)
# Out:
# yr
# 0    37.77
# 1    62.23
# Name: cnt, dtype: float64

# %%
# Ploting a pie chart for better visualisation
plt.figure(figsize=(8,8))
bike.groupby(["yr"])["cnt"].sum().plot.pie()
plt.title("Year wise Bike Rentals",fontsize=20)
plt.show()

# %% [markdown]
# **The above pie shows that there is a considerable increase in year on year bike rentals from 2018 to 2019**

# %%
#Checking the monthly count of rental bikes
round(bike.groupby('mnth')['cnt'].sum()/bike.cnt.sum()*100,2)
# Out:
# mnth
# April         8.18
# August       10.67
# December      6.41
# February      4.54
# January       4.10
# July         10.48
# June         10.52
# March         6.96
# May          10.08
# November      7.74
# October       9.80
# September    10.51
# Name: cnt, dtype: float64

# %%
# Ploting a pie chart for better visualisation
plt.figure(figsize=(8,8))
bike.groupby(["mnth"])["cnt"].sum().plot.pie()
plt.title("Month wise Bike Rentals",fontsize=20)
plt.show()

# %% [markdown]
# **It can be observed that months from April to October has good demand for Bike Rentals**

# %%
# Boxplot for categorical variables to see bike rentals
Categories = ['holiday','weekday','workingday','weathersit']
plt.figure(figsize=(20, 20))
for i in enumerate(Categories):
    plt.subplot(2,2,i[0]+1)
    sns.boxplot(data=bike, x=i[1], y='cnt')
plt.show()

# %% [markdown]
# **It can be seen that the demand for bike rentals is good when there is Pleasant and Moderate Weather**
#
# **No clarity about the demand can be seen when it comes to the weekdays and workingday as the demand seems almost same for all days of the week**
#
# **It can be observed that the demand for bike rentals decreases on holidays**

# %%
#Pairplots to understand the correlations of the variables
plt.figure(figsize=(20,15))
sns.pairplot(bike)
plt.show()

# %%
bike.select_dtypes(include='number').corr()
# Out:
#                   yr   holiday  workingday      temp     atemp       hum
# yr          1.000000  0.008195   -0.002945  0.048789  0.047215 -0.112547  \
# holiday     0.008195  1.000000   -0.252948 -0.028764 -0.032703 -0.015662
# workingday -0.002945 -0.252948    1.000000  0.053470  0.052940  0.023202
# temp        0.048789 -0.028764    0.053470  1.000000  0.991696  0.128565
# atemp       0.047215 -0.032703    0.052940  0.991696  1.000000  0.141512
# hum        -0.112547 -0.015662    0.023202  0.128565  0.141512  1.000000
# windspeed  -0.011624  0.006257   -0.018666 -0.158186 -0.183876 -0.248506
# cnt         0.569728 -0.068764    0.062542  0.627044  0.630685 -0.098543
#
#             windspeed       cnt
# yr          -0.011624  0.569728
# holiday      0.006257 -0.068764
# workingday  -0.018666  0.062542
# temp        -0.158186  0.627044
# atemp       -0.183876  0.630685
# hum         -0.248506 -0.098543
# windspeed    1.000000 -0.235132
# cnt         -0.235132  1.000000

# %% [markdown]
# **From above table and pairplot it can be observed that temp and atemp is highly correlated, we can drop one of the column.**

# %%
# Dropping the atemp column as it is highly correlated to temp
bike.drop('atemp',axis=1,inplace=True)

# %%
# Checking correlation
correlation_matrix = bike.select_dtypes(include='number').corr()

# %%
#Calculating Correlation
bike_corr = bike.select_dtypes(include='number').corr()
plt.figure(figsize=(15,10))

#Drawing Heatmap of correlation
sns.heatmap(bike_corr,annot=True, )
plt.show()

# %% [markdown]
# **Few variables are showing linear relations, so this is a good dataset to form linear regression model.**

# %%
# Checking with regplot the correlation of cnt vs temp
plt.figure(figsize=(6,5),dpi=110)
plt.title("Cnt vs Temp",fontsize=12)
sns.regplot(data=bike,y="cnt",x="temp",line_kws={"color": "red"})
plt.xlabel("Temperature")
plt.show()

# %%
# Checking with regplot the correlation of cnt vs windspeed
plt.figure(figsize=(6,5),dpi=110)
plt.title("Cnt vs Windspeed",fontsize=12)
sns.regplot(data=bike,y="cnt",x="windspeed",line_kws={"color": "red"})
plt.xlabel("Windspeed")
plt.show()

# %%
# Checking with regplot the correlation of cnt vs humidity
plt.figure(figsize=(6,5),dpi=110)
plt.title("Cnt vs Humidity",fontsize=12)
sns.regplot(data=bike,y="cnt",x="hum",line_kws={"color": "red"})
plt.xlabel("Humidity")
plt.show()

# %% [markdown]
# **We can see that there is a positive linear relation of bike rental demand(cnt) and temp but it has negative relation with humidity and windspeed**

# %% [markdown]
# ### Step 4: Data Preparation

# %%
# Get the dummy variables for the feature season, month, weathersit and weekday

bike = pd.get_dummies(data=bike,columns=["season","mnth","weekday"],drop_first=True)
bike = pd.get_dummies(data=bike,columns=["weathersit"]) #first column is not dropped so that the info about severe weather situation.

# %%
# Checking how the dataset looks with dummies
bike.head()
# Out:
#    yr  holiday  workingday       temp      hum  windspeed   cnt
# 0   0        0           0  14.110847  80.5833  10.749882   985  \
# 1   0        0           0  14.902598  69.6087  16.652113   801
# 2   0        0           1   8.050924  43.7273  16.636703  1349
# 3   0        0           1   8.200000  59.0435  10.739832  1562
# 4   0        0           1   9.305237  43.6957  12.522300  1600
#
#    season_Spring  season_Summer  season_Winter  ...  mnth_September
# 0           True          False          False  ...           False  \
# 1           True          False          False  ...           False
# 2           True          False          False  ...           False
# 3           True          False          False  ...           False
# 4           True          False          False  ...           False
#
#    weekday_Monday  weekday_Saturday  weekday_Sunday  weekday_Thursday
# 0           False              True           False             False  \
# 1           False             False            True             False
# 2            True             False           False             False
# 3           False             False           False             False
# 4           False             False           False             False
#
#    weekday_Tuesday  weekday_Wednesday  weathersit_Bad  weathersit_Moderate
# 0            False              False           False                 True  \
# 1            False              False           False                 True
# 2            False              False           False                False
# 3             True              False           False                False
# 4            False               True           False                False
#
#    weathersit_Pleasant
# 0                False
# 1                False
# 2                 True
# 3                 True
# 4                 True
#
# [5 rows x 30 columns]

# %% [markdown]
# ### Splitting the data into test and train datasets

# %%
#Train Test split with 80:20 ratio
np.random.seed(0)
df_train, df_test = train_test_split(bike, train_size = 0.8, test_size = 0.2, random_state = 100)

# %%
df_train.shape
# Out:
# (584, 30)

# %%
df_test.shape
# Out:
# (146, 30)

# %%
### Scaling the model
scaled_var = ['temp','hum','windspeed']

#Use Normalized scaler to scale
scaler = MinMaxScaler()

#Fit and transform training set only
df_train[scaled_var] = scaler.fit_transform(df_train[scaled_var])

# %%
df_train.head()
# Out:
#      yr  holiday  workingday      temp       hum  windspeed   cnt
# 367   1        0           1  0.113228  0.454701   0.695175  2236  \
# 648   1        0           1  0.468352  0.477458   0.299450  7570
# 44    0        0           1  0.443431  0.387290   0.807474  1913
# 705   1        0           1  0.326094  0.787463   0.189819  5008
# 379   1        0           0  0.133996  0.431945   0.449210  2311
#
#      season_Spring  season_Summer  season_Winter  ...  mnth_September
# 367           True          False          False  ...           False  \
# 648          False          False           True  ...           False
# 44            True          False          False  ...           False
# 705          False          False           True  ...           False
# 379           True          False          False  ...           False
#
#      weekday_Monday  weekday_Saturday  weekday_Sunday  weekday_Thursday
# 367           False             False           False             False  \
# 648           False             False           False              True
# 44             True             False           False             False
# 705           False             False           False             False
# 379           False             False            True             False
#
#      weekday_Tuesday  weekday_Wednesday  weathersit_Bad  weathersit_Moderate
# 367             True              False           False                False  \
# 648            False              False           False                False
# 44             False              False           False                False
# 705            False              False           False                 True
# 379            False              False           False                False
#
#      weathersit_Pleasant
# 367                 True
# 648                 True
# 44                  True
# 705                False
# 379                 True
#
# [5 rows x 30 columns]

# %%
df_train.describe()
# Out:
#                yr     holiday  workingday        temp         hum   windspeed
# count  584.000000  584.000000  584.000000  584.000000  584.000000  584.000000  \
# mean     0.513699    0.027397    0.667808    0.537414    0.649499    0.319463
# std      0.500241    0.163378    0.471403    0.225336    0.144219    0.168114
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    0.000000    0.340113    0.535852    0.199177
# 50%      1.000000    0.000000    1.000000    0.545191    0.653714    0.294764
# 75%      1.000000    0.000000    1.000000    0.736512    0.752361    0.410413
# max      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
#
#                cnt
# count   584.000000
# mean   4505.267123
# std    1958.617712
# min      22.000000
# 25%    3070.250000
# 50%    4566.500000
# 75%    6035.750000
# max    8714.000000

# %% [markdown]
# ### Dividing into X and Y sets for the model building

# %%
y_train = df_train.pop('cnt')
X_train = df_train

# %%
# Let's check the correlation coefficients to see which variables are highly correlated
plt.figure(figsize = (25,25))
sns.heatmap(df_train.corr(), annot = True)
plt.show()

# %% [markdown]
# **We can see that few variables are positively correlated and this can be good for us to build a regression model**

# %% [markdown]
# ### Step 5: Building a linear model using RFE

# %%
# We have already imported the required libraries
# Running RFE with the output number of the variable equal to 20
lm = LinearRegression()
lm.fit(X_train, y_train)

# running RFE
rfe = RFE(lm, n_features_to_select=20)
rfe.fit(X_train, y_train)
# Out:
# RFE(estimator=LinearRegression(), n_features_to_select=20)

# %%
list(zip(X_train.columns,rfe.support_,rfe.ranking_))
# Out:
# [('yr', True, 1),
#  ('holiday', True, 1),
#  ('workingday', True, 1),
#  ('temp', True, 1),
#  ('hum', True, 1),
#  ('windspeed', True, 1),
#  ('season_Spring', True, 1),
#  ('season_Summer', True, 1),
#  ('season_Winter', True, 1),
#  ('mnth_August', False, 5),
#  ('mnth_December', True, 1),
#  ('mnth_February', True, 1),
#  ('mnth_January', True, 1),
#  ('mnth_July', True, 1),
#  ('mnth_June', False, 7),
#  ('mnth_March', False, 10),
#  ('mnth_May', False, 4),
#  ('mnth_November', True, 1),
#  ('mnth_October', False, 6),
#  ('mnth_September', True, 1),
#  ('weekday_Monday', False, 2),
#  ('weekday_Saturday', True, 1),
#  ('weekday_Sunday', True, 1),
#  ('weekday_Thursday', False, 8),
#  ('weekday_Tuesday', False, 3),
#  ('weekday_Wednesday', False, 9),
#  ('weathersit_Bad', True, 1),
#  ('weathersit_Moderate', True, 1),
#  ('weathersit_Pleasant', True, 1)]

# %%
col = X_train.columns[rfe.support_]
col
# Out:
# Index(['yr', 'holiday', 'workingday', 'temp', 'hum', 'windspeed',
#        'season_Spring', 'season_Summer', 'season_Winter', 'mnth_December',
#        'mnth_February', 'mnth_January', 'mnth_July', 'mnth_November',
#        'mnth_September', 'weekday_Saturday', 'weekday_Sunday',
#        'weathersit_Bad', 'weathersit_Moderate', 'weathersit_Pleasant'],
#       dtype='object')

# %%
X_train.columns[~rfe.support_]
# Out:
# Index(['mnth_August', 'mnth_June', 'mnth_March', 'mnth_May', 'mnth_October',
#        'weekday_Monday', 'weekday_Thursday', 'weekday_Tuesday',
#        'weekday_Wednesday'],
#       dtype='object')

# %% [markdown]
# ### Building model using statsmodel, for the detailed statistics

# %%
# Creating X_test dataframe with RFE selected variables
X_train_rfe = X_train[col]

# %%
# Adding a constant variable 
X_train_rfe = sm.add_constant(X_train_rfe)

# %%
# Convert to numeric types
X_train_rfe = X_train_rfe.astype(float)
y_train = y_train.astype(float)
print("Missing values in X_train_rfe:", X_train_rfe.isnull().sum())
print("Missing values in y_train:", y_train.isnull().sum())
# Out:
# Missing values in X_train_rfe: const                  0
# yr                     0
# holiday                0
# workingday             0
# temp                   0
# hum                    0
# windspeed              0
# season_Spring          0
# season_Summer          0
# season_Winter          0
# mnth_December          0
# mnth_February          0
# mnth_January           0
# mnth_July              0
# mnth_November          0
# mnth_September         0
# weekday_Saturday       0
# weekday_Sunday         0
# weathersit_Bad         0
# weathersit_Moderate    0
# weathersit_Pleasant    0
# dtype: int64
# Missing values in y_train: 0

# %%
# Running the linear model
lm = sm.OLS(y_train,X_train_rfe).fit()

# %%
#Let's see the summary of our linear model
print(lm.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    cnt   R-squared:                       0.857
# Model:                            OLS   Adj. R-squared:                  0.853
# Method:                 Least Squares   F-statistic:                     188.3
# Date:                Mon, 15 Jan 2024   Prob (F-statistic):          6.51e-225
# Time:                        16:06:13   Log-Likelihood:                -4686.7
# No. Observations:                 584   AIC:                             9411.
# Df Residuals:                     565   BIC:                             9495.
# Df Model:                          18
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                1064.4979    205.579      5.178      0.000     660.705    1468.291
# yr                   1984.1773     63.466     31.264      0.000    1859.520    2108.835
# holiday              -290.0378    163.094     -1.778      0.076    -610.381      30.306
# workingday            571.1153     73.950      7.723      0.000     425.865     716.366
# temp                 4026.4807    300.490     13.400      0.000    3436.266    4616.696
# hum                 -1249.4564    303.292     -4.120      0.000   -1845.174    -653.738
# windspeed           -1610.5980    203.345     -7.921      0.000   -2010.002   -1211.194
# season_Spring        -520.5555    174.021     -2.991      0.003    -862.362    -178.749
# season_Summer         331.5249    120.501      2.751      0.006      94.841     568.209
# season_Winter         940.2352    137.100      6.858      0.000     670.947    1209.523
# mnth_December        -502.1275    142.086     -3.534      0.000    -781.208    -223.047
# mnth_February        -284.7949    165.709     -1.719      0.086    -610.275      40.685
# mnth_January         -536.9621    169.095     -3.176      0.002    -869.093    -204.831
# mnth_July            -443.5797    145.086     -3.057      0.002    -728.554    -158.606
# mnth_November        -512.2529    150.369     -3.407      0.001    -807.604    -216.902
# mnth_September        556.8395    132.048      4.217      0.000     297.474     816.205
# weekday_Saturday      653.8964     90.065      7.260      0.000     476.994     830.799
# weekday_Sunday        129.5239     91.892      1.410      0.159     -50.967     310.015
# weathersit_Bad       -994.6005    171.619     -5.795      0.000   -1331.689    -657.512
# weathersit_Moderate   774.4271     95.103      8.143      0.000     587.628     961.227
# weathersit_Pleasant  1284.6714     82.874     15.501      0.000    1121.892    1447.451
# ==============================================================================
# Omnibus:                      101.291   Durbin-Watson:                   2.053
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              281.722
# Skew:                          -0.853   Prob(JB):                     6.68e-62
# Kurtosis:                       5.944   Cond. No.                     2.40e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 3.4e-30. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
# Calculate the VIFs for the model
vif = pd.DataFrame()
X = X_train_rfe
vif['Features'] = X.columns
vif['VIF'] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
#                Features   VIF
# 20  weathersit_Pleasant   inf
# 16     weekday_Saturday   inf
# 2               holiday   inf
# 3            workingday   inf
# 19  weathersit_Moderate   inf
# 18       weathersit_Bad   inf
# 17       weekday_Sunday   inf
# 7         season_Spring  5.89
# 4                  temp  4.73
# 9         season_Winter  3.64
# 8         season_Summer  2.79
# 12         mnth_January  2.35
# 5                   hum  1.97
# 11        mnth_February  1.93
# 14        mnth_November  1.73
# 10        mnth_December  1.66
# 13            mnth_July  1.51
# 15       mnth_September  1.33
# 6             windspeed  1.20
# 1                    yr  1.04
# 0                 const  0.00

# %% [markdown]
# **We can drop weathersit_Pleasant as it shows infinte VIF which show multicolinearity**

# %%
# Dropping the weathersit_Pleasant column
X_train_new = X_train_rfe.drop(["weathersit_Pleasant"], axis = 1)

# %%
# Creating X_test dataframe after dropping the weathersit_Pleasant
X_train_lm = sm.add_constant(X_train_new)

# Adding a constant variable 
X_train_new = sm.add_constant(X_train_new)

# Running the linear model
lm = sm.OLS(y_train,X_train_new).fit()   

#Let's see the summary of our linear model
print(lm.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    cnt   R-squared:                       0.857
# Model:                            OLS   Adj. R-squared:                  0.853
# Method:                 Least Squares   F-statistic:                     188.3
# Date:                Mon, 15 Jan 2024   Prob (F-statistic):          6.51e-225
# Time:                        16:06:13   Log-Likelihood:                -4686.7
# No. Observations:                 584   AIC:                             9411.
# Df Residuals:                     565   BIC:                             9495.
# Df Model:                          18
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                2092.2350    239.076      8.751      0.000    1622.649    2561.821
# yr                   1984.1773     63.466     31.264      0.000    1859.520    2108.835
# holiday               -33.1035    167.645     -0.197      0.844    -362.388     296.181
# workingday            828.0496     78.838     10.503      0.000     673.198     982.901
# temp                 4026.4807    300.490     13.400      0.000    3436.266    4616.696
# hum                 -1249.4564    303.292     -4.120      0.000   -1845.174    -653.738
# windspeed           -1610.5980    203.345     -7.921      0.000   -2010.002   -1211.194
# season_Spring        -520.5555    174.021     -2.991      0.003    -862.362    -178.749
# season_Summer         331.5249    120.501      2.751      0.006      94.841     568.209
# season_Winter         940.2352    137.100      6.858      0.000     670.947    1209.523
# mnth_December        -502.1275    142.086     -3.534      0.000    -781.208    -223.047
# mnth_February        -284.7949    165.709     -1.719      0.086    -610.275      40.685
# mnth_January         -536.9621    169.095     -3.176      0.002    -869.093    -204.831
# mnth_July            -443.5797    145.086     -3.057      0.002    -728.554    -158.606
# mnth_November        -512.2529    150.369     -3.407      0.001    -807.604    -216.902
# mnth_September        556.8395    132.048      4.217      0.000     297.474     816.205
# weekday_Saturday      910.8307     94.466      9.642      0.000     725.283    1096.378
# weekday_Sunday        386.4582     95.411      4.050      0.000     199.055     573.862
# weathersit_Bad      -2279.2719    214.323    -10.635      0.000   -2700.240   -1858.304
# weathersit_Moderate  -510.2443     83.140     -6.137      0.000    -673.545    -346.943
# ==============================================================================
# Omnibus:                      101.291   Durbin-Watson:                   2.053
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              281.722
# Skew:                          -0.853   Prob(JB):                     6.68e-62
# Kurtosis:                       5.944   Cond. No.                     9.68e+15
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.86e-29. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
vif = pd.DataFrame()
X = X_train_new
vif['Features'] = X.columns
vif['VIF'] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
#                Features   VIF
# 2               holiday   inf
# 3            workingday   inf
# 17       weekday_Sunday   inf
# 16     weekday_Saturday   inf
# 7         season_Spring  5.89
# 4                  temp  4.73
# 9         season_Winter  3.64
# 8         season_Summer  2.79
# 12         mnth_January  2.35
# 5                   hum  1.97
# 11        mnth_February  1.93
# 14        mnth_November  1.73
# 10        mnth_December  1.66
# 19  weathersit_Moderate  1.61
# 13            mnth_July  1.51
# 15       mnth_September  1.33
# 18       weathersit_Bad  1.26
# 6             windspeed  1.20
# 1                    yr  1.04
# 0                 const  0.00

# %% [markdown]
# **We can drop weekday_Sunday as it is negative coefficient and high p-value**

# %%
# Dropping the weekday_Sunday column
X_train_new = X_train_new.drop(["weekday_Sunday"], axis = 1)

# Adding a constant variable 
X_train_new = sm.add_constant(X_train_new)

# Running the linear model
lm = sm.OLS(y_train,X_train_new).fit()   

#Let's see the summary of our linear model
print(lm.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    cnt   R-squared:                       0.857
# Model:                            OLS   Adj. R-squared:                  0.853
# Method:                 Least Squares   F-statistic:                     188.3
# Date:                Mon, 15 Jan 2024   Prob (F-statistic):          6.51e-225
# Time:                        16:06:13   Log-Likelihood:                -4686.7
# No. Observations:                 584   AIC:                             9411.
# Df Residuals:                     565   BIC:                             9495.
# Df Model:                          18
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                2478.6932    302.710      8.188      0.000    1884.118    3073.268
# yr                   1984.1773     63.466     31.264      0.000    1859.520    2108.835
# holiday              -419.5617    206.636     -2.030      0.043    -825.430     -13.693
# workingday            441.5914     88.462      4.992      0.000     267.836     615.347
# temp                 4026.4807    300.490     13.400      0.000    3436.266    4616.696
# hum                 -1249.4564    303.292     -4.120      0.000   -1845.174    -653.738
# windspeed           -1610.5980    203.345     -7.921      0.000   -2010.002   -1211.194
# season_Spring        -520.5555    174.021     -2.991      0.003    -862.362    -178.749
# season_Summer         331.5249    120.501      2.751      0.006      94.841     568.209
# season_Winter         940.2352    137.100      6.858      0.000     670.947    1209.523
# mnth_December        -502.1275    142.086     -3.534      0.000    -781.208    -223.047
# mnth_February        -284.7949    165.709     -1.719      0.086    -610.275      40.685
# mnth_January         -536.9621    169.095     -3.176      0.002    -869.093    -204.831
# mnth_July            -443.5797    145.086     -3.057      0.002    -728.554    -158.606
# mnth_November        -512.2529    150.369     -3.407      0.001    -807.604    -216.902
# mnth_September        556.8395    132.048      4.217      0.000     297.474     816.205
# weekday_Saturday      524.3725    113.417      4.623      0.000     301.602     747.143
# weathersit_Bad      -2279.2719    214.323    -10.635      0.000   -2700.240   -1858.304
# weathersit_Moderate  -510.2443     83.140     -6.137      0.000    -673.545    -346.943
# ==============================================================================
# Omnibus:                      101.291   Durbin-Watson:                   2.053
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              281.722
# Skew:                          -0.853   Prob(JB):                     6.68e-62
# Kurtosis:                       5.944   Cond. No.                         23.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
vif = pd.DataFrame()
X = X_train_new
vif['Features'] = X.columns
vif['VIF'] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
#                Features    VIF
# 0                 const  94.61
# 7         season_Spring   5.89
# 4                  temp   4.73
# 9         season_Winter   3.64
# 8         season_Summer   2.79
# 12         mnth_January   2.35
# 5                   hum   1.97
# 11        mnth_February   1.93
# 3            workingday   1.79
# 14        mnth_November   1.73
# 16     weekday_Saturday   1.70
# 10        mnth_December   1.66
# 18  weathersit_Moderate   1.61
# 13            mnth_July   1.51
# 15       mnth_September   1.33
# 17       weathersit_Bad   1.26
# 6             windspeed   1.20
# 2               holiday   1.17
# 1                    yr   1.04

# %% [markdown]
# **We can drop weekday_Saturday as it shows negative coefficient and high p-value**

# %%
# Dropping the weekday_Saturday column
X_train_new = X_train_new.drop(["weekday_Saturday"], axis = 1)

# Creating X_test dataframe after dropping the weekday_Saturday
X_train_lm = sm.add_constant(X_train_new)

# %%
# Running the linear model
lm = sm.OLS(y_train,X_train_lm).fit()

# %%
#Let's see the summary of our linear model
print(lm.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    cnt   R-squared:                       0.852
# Model:                            OLS   Adj. R-squared:                  0.847
# Method:                 Least Squares   F-statistic:                     191.2
# Date:                Mon, 15 Jan 2024   Prob (F-statistic):          1.59e-221
# Time:                        16:06:14   Log-Likelihood:                -4697.6
# No. Observations:                 584   AIC:                             9431.
# Df Residuals:                     566   BIC:                             9510.
# Df Model:                          17
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                2766.0246    301.548      9.173      0.000    2173.735    3358.314
# yr                   1976.5831     64.576     30.609      0.000    1849.745    2103.421
# holiday              -677.2539    202.527     -3.344      0.001   -1075.050    -279.458
# workingday            181.7675     69.537      2.614      0.009      45.185     318.350
# temp                 4049.8924    305.808     13.243      0.000    3449.235    4650.550
# hum                 -1332.0240    308.168     -4.322      0.000   -1937.316    -726.732
# windspeed           -1576.3129    206.835     -7.621      0.000   -1982.570   -1170.056
# season_Spring        -526.7268    177.120     -2.974      0.003    -874.620    -178.834
# season_Summer         322.4259    122.634      2.629      0.009      81.552     563.300
# season_Winter         937.4470    139.545      6.718      0.000     663.358    1211.536
# mnth_December        -483.4769    144.562     -3.344      0.001    -767.421    -199.533
# mnth_February        -295.7659    168.648     -1.754      0.080    -627.018      35.486
# mnth_January         -530.4005    172.105     -3.082      0.002    -868.444    -192.357
# mnth_July            -455.0602    147.653     -3.082      0.002    -745.075    -165.046
# mnth_November        -520.1108    153.042     -3.398      0.001    -820.711    -219.511
# mnth_September        568.2347    134.381      4.229      0.000     304.289     832.181
# weathersit_Bad      -2223.0445    217.796    -10.207      0.000   -2650.831   -1795.258
# weathersit_Moderate  -485.7448     84.451     -5.752      0.000    -651.620    -319.869
# ==============================================================================
# Omnibus:                       86.924   Durbin-Watson:                   2.025
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              246.227
# Skew:                          -0.729   Prob(JB):                     3.41e-54
# Kurtosis:                       5.828   Cond. No.                         23.6
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# Calculate the VIFs for the model
vif = pd.DataFrame()
X = X_train_new
vif['Features'] = X.columns
vif['VIF'] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
#                Features    VIF
# 0                 const  90.62
# 7         season_Spring   5.89
# 4                  temp   4.72
# 9         season_Winter   3.64
# 8         season_Summer   2.78
# 12         mnth_January   2.35
# 5                   hum   1.97
# 11        mnth_February   1.93
# 14        mnth_November   1.73
# 10        mnth_December   1.66
# 17  weathersit_Moderate   1.60
# 13            mnth_July   1.51
# 15       mnth_September   1.33
# 16       weathersit_Bad   1.26
# 6             windspeed   1.20
# 2               holiday   1.09
# 3            workingday   1.07
# 1                    yr   1.04

# %% [markdown]
# **We can drop mnth_February as it shows negative coefficient and high p-value**

# %%
# Dropping the mnth_February column
X_train_new = X_train_new.drop(["mnth_February"], axis = 1)

# Creating X_test dataframe after dropping the mnth_February
X_train_lm = sm.add_constant(X_train_new)

# %%
# Running the linear model
lm = sm.OLS(y_train,X_train_lm).fit()

# %%
#Let's see the summary of our linear model
print(lm.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    cnt   R-squared:                       0.851
# Model:                            OLS   Adj. R-squared:                  0.847
# Method:                 Least Squares   F-statistic:                     202.2
# Date:                Mon, 15 Jan 2024   Prob (F-statistic):          5.05e-222
# Time:                        16:06:14   Log-Likelihood:                -4699.2
# No. Observations:                 584   AIC:                             9432.
# Df Residuals:                     567   BIC:                             9507.
# Df Model:                          16
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                2676.8872    297.777      8.990      0.000    2092.006    3261.768
# yr                   1972.4390     64.651     30.509      0.000    1845.454    2099.424
# holiday              -689.0452    202.785     -3.398      0.001   -1087.347    -290.743
# workingday            181.2959     69.664      2.602      0.009      44.465     318.127
# temp                 4179.6804    297.261     14.061      0.000    3595.814    4763.547
# hum                 -1354.8669    308.455     -4.392      0.000   -1960.721    -749.012
# windspeed           -1571.2309    207.193     -7.583      0.000   -1978.190   -1164.272
# season_Spring        -617.0070    169.784     -3.634      0.000    -950.490    -283.524
# season_Summer         348.6562    121.941      2.859      0.004     109.144     588.168
# season_Winter         948.6980    139.652      6.793      0.000     674.399    1222.997
# mnth_December        -396.9863    136.138     -2.916      0.004    -664.383    -129.590
# mnth_January         -363.9539    143.833     -2.530      0.012    -646.465     -81.443
# mnth_July            -462.9091    147.855     -3.131      0.002    -753.319    -172.499
# mnth_November        -477.8210    151.407     -3.156      0.002    -775.208    -180.434
# mnth_September        580.8702    134.433      4.321      0.000     316.823     844.917
# weathersit_Bad      -2203.7764    217.916    -10.113      0.000   -2631.798   -1775.755
# weathersit_Moderate  -484.0265     84.600     -5.721      0.000    -650.194    -317.859
# ==============================================================================
# Omnibus:                       81.166   Durbin-Watson:                   2.029
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              230.515
# Skew:                          -0.680   Prob(JB):                     8.80e-51
# Kurtosis:                       5.761   Cond. No.                         23.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# Calculate the VIFs for the model
vif = pd.DataFrame()
X = X_train_new
vif['Features'] = X.columns
vif['VIF'] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
#                Features    VIF
# 0                 const  88.05
# 7         season_Spring   5.39
# 4                  temp   4.45
# 9         season_Winter   3.63
# 8         season_Summer   2.74
# 5                   hum   1.96
# 13        mnth_November   1.68
# 11         mnth_January   1.64
# 16  weathersit_Moderate   1.60
# 12            mnth_July   1.51
# 10        mnth_December   1.47
# 14       mnth_September   1.33
# 15       weathersit_Bad   1.26
# 6             windspeed   1.20
# 2               holiday   1.09
# 3            workingday   1.07
# 1                    yr   1.04

# %% [markdown]
# **We can drop mnth_January as it shows negative coefficient and high p-value**

# %%
# Dropping the mnth_January column
X_train_new = X_train_new.drop(["mnth_January"], axis = 1)

# Creating X_test dataframe after dropping the mnth_January
X_train_lm = sm.add_constant(X_train_new)

# %%
# Running the linear model
lm = sm.OLS(y_train,X_train_lm).fit()

# %%
#Let's see the summary of our linear model
print(lm.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    cnt   R-squared:                       0.849
# Model:                            OLS   Adj. R-squared:                  0.845
# Method:                 Least Squares   F-statistic:                     213.3
# Date:                Mon, 15 Jan 2024   Prob (F-statistic):          8.09e-222
# Time:                        16:06:14   Log-Likelihood:                -4702.4
# No. Observations:                 584   AIC:                             9437.
# Df Residuals:                     568   BIC:                             9507.
# Df Model:                          15
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                2515.6118    292.256      8.608      0.000    1941.577    3089.647
# yr                   1963.3912     64.858     30.272      0.000    1836.000    2090.782
# holiday              -711.6294    203.550     -3.496      0.001   -1111.432    -311.827
# workingday            179.3627     69.990      2.563      0.011      41.891     316.834
# temp                 4427.6119    281.980     15.702      0.000    3873.761    4981.463
# hum                 -1420.0014    308.838     -4.598      0.000   -2026.605    -813.398
# windspeed           -1532.2810    207.600     -7.381      0.000   -1940.039   -1124.523
# season_Spring        -638.6934    170.372     -3.749      0.000    -973.330    -304.057
# season_Summer         393.4826    121.220      3.246      0.001     155.388     631.577
# season_Winter         992.4162    139.237      7.128      0.000     718.934    1265.898
# mnth_December        -302.4211    131.529     -2.299      0.022    -560.764     -44.078
# mnth_July            -480.8392    148.386     -3.240      0.001    -772.291    -189.387
# mnth_November        -423.8098    150.606     -2.814      0.005    -719.623    -127.997
# mnth_September        598.0310    134.899      4.433      0.000     333.070     862.992
# weathersit_Bad      -2158.7588    218.219     -9.893      0.000   -2587.374   -1730.144
# weathersit_Moderate  -477.3787     84.960     -5.619      0.000    -644.253    -310.504
# ==============================================================================
# Omnibus:                       76.188   Durbin-Watson:                   2.031
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              213.230
# Skew:                          -0.643   Prob(JB):                     4.99e-47
# Kurtosis:                       5.667   Cond. No.                         22.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# Calculate the VIFs for the model
vif = pd.DataFrame()
X = X_train_new
vif['Features'] = X.columns
vif['VIF'] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
#                Features    VIF
# 0                 const  84.01
# 7         season_Spring   5.38
# 4                  temp   3.96
# 9         season_Winter   3.58
# 8         season_Summer   2.69
# 5                   hum   1.95
# 12        mnth_November   1.65
# 15  weathersit_Moderate   1.60
# 11            mnth_July   1.51
# 10        mnth_December   1.36
# 13       mnth_September   1.32
# 14       weathersit_Bad   1.25
# 6             windspeed   1.20
# 2               holiday   1.09
# 3            workingday   1.07
# 1                    yr   1.03

# %% [markdown]
# **We can drop mnth_December as it shows negative coefficient and high p-value**

# %%
# Dropping the mnth_December column
X_train_new = X_train_new.drop(["mnth_December"], axis = 1)

# Creating X_test dataframe after dropping the mnth_December
X_train_lm = sm.add_constant(X_train_new)

# %%
# Running the linear model
lm = sm.OLS(y_train,X_train_lm).fit()

# %%
#Let's see the summary of our linear model
print(lm.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    cnt   R-squared:                       0.848
# Model:                            OLS   Adj. R-squared:                  0.844
# Method:                 Least Squares   F-statistic:                     226.4
# Date:                Mon, 15 Jan 2024   Prob (F-statistic):          7.25e-222
# Time:                        16:06:14   Log-Likelihood:                -4705.2
# No. Observations:                 584   AIC:                             9440.
# Df Residuals:                     569   BIC:                             9506.
# Df Model:                          14
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                2404.3153    289.304      8.311      0.000    1836.082    2972.548
# yr                   1958.3419     65.065     30.098      0.000    1830.545    2086.138
# holiday              -732.1958    204.118     -3.587      0.000   -1133.112    -331.279
# workingday            178.4385     70.252      2.540      0.011      40.453     316.424
# temp                 4605.7947    272.141     16.924      0.000    4071.270    5140.319
# hum                 -1489.0212    308.531     -4.826      0.000   -2095.020    -883.022
# windspeed           -1516.1332    208.262     -7.280      0.000   -1925.189   -1107.078
# season_Spring        -583.0964    169.282     -3.445      0.001    -915.590    -250.603
# season_Summer         434.9149    120.324      3.615      0.000     198.581     671.248
# season_Winter         952.1358    138.650      6.867      0.000     679.808    1224.463
# mnth_July            -483.5765    148.939     -3.247      0.001    -776.114    -191.039
# mnth_November        -302.9741    141.670     -2.139      0.033    -581.234     -24.715
# mnth_September        638.6618    134.239      4.758      0.000     374.997     902.326
# weathersit_Bad      -2130.3592    218.689     -9.742      0.000   -2559.894   -1700.824
# weathersit_Moderate  -463.1717     85.054     -5.446      0.000    -630.229    -296.114
# ==============================================================================
# Omnibus:                       69.651   Durbin-Watson:                   2.043
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              183.399
# Skew:                          -0.606   Prob(JB):                     1.50e-40
# Kurtosis:                       5.463   Cond. No.                         22.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# Calculate the VIFs for the model
vif = pd.DataFrame()
X = X_train_new
vif['Features'] = X.columns
vif['VIF'] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
#                Features    VIF
# 0                 const  81.71
# 7         season_Spring   5.27
# 4                  temp   3.66
# 9         season_Winter   3.52
# 8         season_Summer   2.63
# 5                   hum   1.93
# 14  weathersit_Moderate   1.59
# 10            mnth_July   1.51
# 11        mnth_November   1.45
# 12       mnth_September   1.30
# 13       weathersit_Bad   1.24
# 6             windspeed   1.19
# 2               holiday   1.08
# 3            workingday   1.07
# 1                    yr   1.03

# %% [markdown]
# **We can drop mnth_November as it shows negative coefficient and high p-value**

# %%
# Dropping the mnth_November column
X_train_new = X_train_new.drop(["mnth_November"], axis = 1)

# Creating X_test dataframe after dropping the mnth_November
X_train_lm = sm.add_constant(X_train_new)

# %%
# Running the linear model
lm = sm.OLS(y_train,X_train_lm).fit()

# %%
#Let's see the summary of our linear model
print(lm.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    cnt   R-squared:                       0.847
# Model:                            OLS   Adj. R-squared:                  0.843
# Method:                 Least Squares   F-statistic:                     242.0
# Date:                Mon, 15 Jan 2024   Prob (F-statistic):          4.42e-222
# Time:                        16:06:15   Log-Likelihood:                -4707.5
# No. Observations:                 584   AIC:                             9443.
# Df Residuals:                     570   BIC:                             9504.
# Df Model:                          13
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                2310.3184    286.840      8.054      0.000    1746.926    2873.711
# yr                   1959.3461     65.267     30.021      0.000    1831.153    2087.539
# holiday              -779.2587    203.563     -3.828      0.000   -1179.085    -379.433
# workingday            177.6976     70.471      2.522      0.012      39.282     316.113
# temp                 4705.1519    268.986     17.492      0.000    4176.828    5233.476
# hum                 -1474.0686    309.417     -4.764      0.000   -2081.806    -866.331
# windspeed           -1536.1765    208.702     -7.361      0.000   -1946.095   -1126.258
# season_Spring        -519.6644    167.185     -3.108      0.002    -848.037    -191.291
# season_Summer         464.8707    119.880      3.878      0.000     229.410     700.331
# season_Winter         894.9931    136.476      6.558      0.000     626.935    1163.051
# mnth_July            -479.1231    149.390     -3.207      0.001    -772.546    -185.700
# mnth_September        671.7185    133.764      5.022      0.000     408.989     934.448
# weathersit_Bad      -2117.0730    219.284     -9.654      0.000   -2547.777   -1686.369
# weathersit_Moderate  -458.0615     85.286     -5.371      0.000    -625.575    -290.548
# ==============================================================================
# Omnibus:                       68.428   Durbin-Watson:                   2.054
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              176.753
# Skew:                          -0.602   Prob(JB):                     4.16e-39
# Kurtosis:                       5.411   Cond. No.                         21.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# Calculate the VIFs for the model
vif = pd.DataFrame()
X = X_train_new
vif['Features'] = X.columns
vif['VIF'] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
#                Features    VIF
# 0                 const  79.82
# 7         season_Spring   5.11
# 4                  temp   3.56
# 9         season_Winter   3.39
# 8         season_Summer   2.59
# 5                   hum   1.93
# 13  weathersit_Moderate   1.59
# 10            mnth_July   1.51
# 11       mnth_September   1.28
# 12       weathersit_Bad   1.24
# 6             windspeed   1.19
# 2               holiday   1.07
# 3            workingday   1.07
# 1                    yr   1.03

# %% [markdown]
# **We can drop workingday as it shows negative coefficient and high p-value**

# %%
# Dropping the workingday column
X_train_new = X_train_new.drop(["workingday"], axis = 1)

# Creating X_test dataframe after dropping the workingday
X_train_lm = sm.add_constant(X_train_new)

# %%
# Running the linear model
lm = sm.OLS(y_train,X_train_lm).fit()

# %%
#Let's see the summary of our linear model
print(lm.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    cnt   R-squared:                       0.845
# Model:                            OLS   Adj. R-squared:                  0.842
# Method:                 Least Squares   F-statistic:                     259.2
# Date:                Mon, 15 Jan 2024   Prob (F-statistic):          6.27e-222
# Time:                        16:06:15   Log-Likelihood:                -4710.7
# No. Observations:                 584   AIC:                             9447.
# Df Residuals:                     571   BIC:                             9504.
# Df Model:                          12
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                2421.3237    284.769      8.503      0.000    1862.002    2980.646
# yr                   1965.0593     65.533     29.986      0.000    1836.345    2093.774
# holiday              -898.0001    198.969     -4.513      0.000   -1288.800    -507.200
# temp                 4730.2076    270.060     17.515      0.000    4199.775    5260.641
# hum                 -1481.7170    310.851     -4.767      0.000   -2092.267    -871.167
# windspeed           -1548.6546    209.620     -7.388      0.000   -1960.374   -1136.935
# season_Spring        -517.1283    167.964     -3.079      0.002    -847.031    -187.225
# season_Summer         466.7442    120.439      3.875      0.000     230.187     703.301
# season_Winter         895.3543    137.115      6.530      0.000     626.043    1164.666
# mnth_July            -492.6945    149.992     -3.285      0.001    -787.298    -198.091
# mnth_September        666.6541    134.375      4.961      0.000     402.725     930.583
# weathersit_Bad      -2096.4946    220.158     -9.523      0.000   -2528.914   -1664.076
# weathersit_Moderate  -448.8774     85.607     -5.243      0.000    -617.021    -280.734
# ==============================================================================
# Omnibus:                       75.269   Durbin-Watson:                   2.039
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              175.313
# Skew:                          -0.695   Prob(JB):                     8.54e-39
# Kurtosis:                       5.297   Cond. No.                         19.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# Calculate the VIFs for the model
vif = pd.DataFrame()
X = X_train_new
vif['Features'] = X.columns
vif['VIF'] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
#                Features    VIF
# 0                 const  77.94
# 6         season_Spring   5.11
# 3                  temp   3.55
# 8         season_Winter   3.39
# 7         season_Summer   2.59
# 4                   hum   1.93
# 12  weathersit_Moderate   1.59
# 9             mnth_July   1.51
# 10       mnth_September   1.28
# 11       weathersit_Bad   1.24
# 5             windspeed   1.19
# 1                    yr   1.03
# 2               holiday   1.01

# %%
#Dropping the const since VIF is high (VIF < 3 is ideal but less than 10 is acceptable)
X_train_new = X_train_new.drop(['const'], axis=1)

# Creating X_test dataframe after dropping the const
X_train_lm = sm.add_constant(X_train_new)

# Running the linear model
lm = sm.OLS(y_train,X_train_lm).fit()

#Let's see the summary of our linear model
print(lm.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    cnt   R-squared:                       0.845
# Model:                            OLS   Adj. R-squared:                  0.842
# Method:                 Least Squares   F-statistic:                     259.2
# Date:                Mon, 15 Jan 2024   Prob (F-statistic):          6.27e-222
# Time:                        16:06:15   Log-Likelihood:                -4710.7
# No. Observations:                 584   AIC:                             9447.
# Df Residuals:                     571   BIC:                             9504.
# Df Model:                          12
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                2421.3237    284.769      8.503      0.000    1862.002    2980.646
# yr                   1965.0593     65.533     29.986      0.000    1836.345    2093.774
# holiday              -898.0001    198.969     -4.513      0.000   -1288.800    -507.200
# temp                 4730.2076    270.060     17.515      0.000    4199.775    5260.641
# hum                 -1481.7170    310.851     -4.767      0.000   -2092.267    -871.167
# windspeed           -1548.6546    209.620     -7.388      0.000   -1960.374   -1136.935
# season_Spring        -517.1283    167.964     -3.079      0.002    -847.031    -187.225
# season_Summer         466.7442    120.439      3.875      0.000     230.187     703.301
# season_Winter         895.3543    137.115      6.530      0.000     626.043    1164.666
# mnth_July            -492.6945    149.992     -3.285      0.001    -787.298    -198.091
# mnth_September        666.6541    134.375      4.961      0.000     402.725     930.583
# weathersit_Bad      -2096.4946    220.158     -9.523      0.000   -2528.914   -1664.076
# weathersit_Moderate  -448.8774     85.607     -5.243      0.000    -617.021    -280.734
# ==============================================================================
# Omnibus:                       75.269   Durbin-Watson:                   2.039
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              175.313
# Skew:                          -0.695   Prob(JB):                     8.54e-39
# Kurtosis:                       5.297   Cond. No.                         19.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
vif = pd.DataFrame()
X = X_train_new
vif['Features'] = X.columns
vif['VIF'] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
#                Features    VIF
# 3                   hum  27.87
# 2                  temp  16.00
# 4             windspeed   4.63
# 5         season_Spring   4.12
# 7         season_Winter   3.26
# 6         season_Summer   2.77
# 11  weathersit_Moderate   2.28
# 0                    yr   2.09
# 8             mnth_July   1.60
# 9        mnth_September   1.38
# 10       weathersit_Bad   1.23
# 1               holiday   1.04

# %%
#Dropping the const since VIF is high (VIF < 3 is ideal but less than 10 is acceptable)
X_train_new = X_train_new.drop(['hum'], axis=1)

# Creating X_test dataframe after dropping the const
X_train_lm = sm.add_constant(X_train_new)

# Running the linear model
lm = sm.OLS(y_train,X_train_lm).fit()

#Let's see the summary of our linear model
print(lm.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    cnt   R-squared:                       0.839
# Model:                            OLS   Adj. R-squared:                  0.836
# Method:                 Least Squares   F-statistic:                     270.4
# Date:                Mon, 15 Jan 2024   Prob (F-statistic):          2.48e-218
# Time:                        16:06:15   Log-Likelihood:                -4722.1
# No. Observations:                 584   AIC:                             9468.
# Df Residuals:                     572   BIC:                             9521.
# Df Model:                          11
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                1651.0461    238.888      6.911      0.000    1181.842    2120.250
# yr                   2007.0535     66.159     30.337      0.000    1877.109    2136.998
# holiday              -896.8652    202.711     -4.424      0.000   -1295.014    -498.716
# temp                 4435.6096    267.838     16.561      0.000    3909.543    4961.676
# windspeed           -1258.3021    204.347     -6.158      0.000   -1659.664    -856.940
# season_Spring        -585.9201    170.491     -3.437      0.001    -920.784    -251.056
# season_Summer         428.4162    122.431      3.499      0.001     187.948     668.884
# season_Winter         784.9899    137.688      5.701      0.000     514.554    1055.426
# mnth_July            -445.0017    152.473     -2.919      0.004    -744.477    -145.526
# mnth_September        615.1577    136.459      4.508      0.000     347.136     883.179
# weathersit_Bad      -2513.9876    205.785    -12.217      0.000   -2918.175   -2109.801
# weathersit_Moderate  -687.6975     70.720     -9.724      0.000    -826.600    -548.794
# ==============================================================================
# Omnibus:                       73.472   Durbin-Watson:                   2.042
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              167.274
# Skew:                          -0.687   Prob(JB):                     4.75e-37
# Kurtosis:                       5.234   Cond. No.                         17.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# Calculate the VIFs for the model after dropping the const
vif = pd.DataFrame()
X = X_train_new
vif['Features'] = X.columns
vif['VIF'] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif['VIF'] = round(vif['VIF'], 2)
vif = vif.sort_values(by = "VIF", ascending = False)
vif
# Out:
#                Features   VIF
# 2                  temp  5.23
# 3             windspeed  4.59
# 5         season_Summer  2.27
# 4         season_Spring  2.14
# 0                    yr  2.07
# 6         season_Winter  1.79
# 7             mnth_July  1.60
# 10  weathersit_Moderate  1.55
# 8        mnth_September  1.34
# 9        weathersit_Bad  1.07
# 1               holiday  1.04

# %% [markdown]
# **Now that we VIF which is acceptable andp-value for all the features is almost 0.0 and R2 is 0.839 we will go with this model as our final model as it has all important statistics like high (R-square, Adjusted R-squared and F-statistic), Also it shows no insignificant variables and no multicollinearty (high VIF) variables. The difference between R-square and Adjusted R-square is 0.003 which shows that no further variables are required to be removed from this model.**

# %% [markdown]
# ### Step 7. Model Evaluation
# ### Residual Analysis

# %%
y_train_cnt = lm.predict(X_train_lm)

# %%
# Plot the histogram of the error terms to check the normality of the errors
fig = plt.figure()
sns.distplot((y_train - y_train_cnt), bins = 20)
fig.suptitle('Error Terms', fontsize = 20)                  # Plot heading 
plt.xlabel('Errors', fontsize = 18)                         # X-label
plt.show()

# %% [markdown]
# Residuals distribution should follow normal distribution and centred around 0.(mean = 0).
# We validate this assumption about residuals by plotting a distplot of residuals and see if
# residuals are following normal distribution or not.The above diagram shows that the residuals are
# distributed about mean = 0.

# %% [markdown]
# ## Step 8: Making Predictions Using the Final Model
#
# Now that we have fitted the model and checked the normality of error terms, it's time to go ahead and make predictions using the final model

# %% [markdown]
# #### Applying the scaling on the test sets

# %%
num_vars = ['temp', 'hum','windspeed']

df_test[num_vars] = scaler.transform(df_test[num_vars])

# %%
df_test.describe()
# Out:
#                yr     holiday  workingday        temp         hum   windspeed
# count  146.000000  146.000000  146.000000  146.000000  146.000000  146.000000  \
# mean     0.445205    0.034247    0.746575    0.569603    0.635933    0.315127
# std      0.498699    0.182488    0.436469    0.238088    0.156357    0.161524
# min      0.000000    0.000000    0.000000    0.046591    0.261915   -0.042808
# 25%      0.000000    0.000000    0.250000    0.359075    0.534457    0.196160
# 50%      0.000000    0.000000    1.000000    0.560248    0.614856    0.306383
# 75%      1.000000    0.000000    1.000000    0.801929    0.730570    0.411976
# max      1.000000    1.000000    1.000000    0.984424    1.002146    0.800793
#
#                cnt
# count   146.000000
# mean   4518.965753
# std    1849.283281
# min     506.000000
# 25%    3422.750000
# 50%    4445.500000
# 75%    5671.750000
# max    8395.000000

# %% [markdown]
# #### Dividing into X_test and y_test

# %%
y_test = df_test.pop('cnt')
X_test = df_test

# %%
# Now let's use our model to make predictions.

# Creating X_test_new dataframe by dropping variables from X_test
X_test_new = X_test[X_train_new.columns]

# Adding a constant variable 
X_test_new = sm.add_constant(X_test_new)

# %%
# Making predictions
y_pred = lm.predict(X_test_new)

# %%
# Plotting y_test and y_pred to understand the spread.
fig = plt.figure()
plt.scatter(y_test,y_pred)
fig.suptitle('y_test vs y_pred', fontsize=20)              # Plot heading 
plt.xlabel('y_test', fontsize=18)                          # X-label
plt.ylabel('y_pred', fontsize=16)                          # Y-label
plt.show()

# %% [markdown]
# ### Checking weather the error terms are independent of each other.

# %%
r2_score(y_test, y_pred)
# Out:
# 0.7703949799381988

# %% [markdown]
# **R2 score has negligible difference, so we can infer this is the good to go model**

# %% [markdown]
# ### Key points from the  the above model, BoomBikes should focus while going ahead with expansion plans:
# - Company should focus on expanding business during Fall, Summer and Winter
# - September month has shown great demand.
# - It has been observed that the demand for bike rentals had gone up from 2018 to 2019. So we can say that it will go up once the situation gets normal post Covid
# - There would be less bookings during Bad and no demand in Severe weather conditions.
# - There is no much demand during the holidays

# %% [markdown]
# ### Significant variables to predict the demand for shared bikes
# - holiday
# - temp
# - windspeed
# - Season - (Summer, Spring and Winter)
# - months(July, September)
# - Year
# - weathersit (Bad and Moderate)
